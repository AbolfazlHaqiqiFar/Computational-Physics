# %%
from ode import euler_method_plot, picard_method_plot, predictor_corrector_plot
m = 1.0 
k = 1.0 
x0 = 1.0
v0 = 0.0
b = 0.5
num_steps = 1000
total_time = 100.0 
h = total_time / num_steps  # step size

# %%
euler_method_plot(h, m, k, x0, v0, num_steps)

# %%
picard_method_plot(h, num_steps, m, k)

# %%
predictor_corrector_plot(x0 ,v0 , total_time, h, b, k)
